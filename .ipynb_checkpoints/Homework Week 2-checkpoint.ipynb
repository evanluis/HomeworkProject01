# %% [markdown]
# Homework Week 2
# Media Practices: Programming
# This assignment is mostly about practicing manipulating numbers and strings in python. It ends with backing an algorithm out of code.

# %% [markdown]
# Write code that when you run the cell generates a tic-tac-toe board
# Expected output:
#
#   |  |
# --------
#   |  |
# --------
#   |  |
#
# First just use print statements

# %%
print ('   |   |   ')
print ('-----------')
print ('   |   |   ')
print ('-----------')
print ('   |   |   ')
# Out:
#    |   |
# -----------
#    |   |
# -----------
#    |   |

# %% [markdown]
# Now do it using variables

# %%
vet = '   |   |   '
horz = '-----------'
print vet
print horz
print vet
print horz
print vet
# Out:
#    |   |
# -----------
#    |   |
# -----------
#    |   |

# %% [markdown]
# Starting with x and y as defined, write code to print the larger number

# %%
x = 54
y = 23

#your code...
list = [x,y]
print max(list)
# Out:
# 54

# %% [markdown]
# Starting with x, y, and z as defined, write code to print the largest number

# %%
x = -54
y = 23
z = 4

#your code...
list = (x, y, z)
print max(list)
# Out:
# 23

# %% [raw]
# #Write a vowel recognizer
# #'''some other code to ignore
# #original = raw.input('Enter a word:')
# #word = original.lower()
# #vowel_list = ('a', 'e' ,'i', 'o', 'u')'''
#
# letter = input("Enter a letter:")
#     if letter == ('a', or 'e', or 'i', or 'o', or 'u'):
#     print (letter, " is a vowel.")
#
#     elif letter == ('y')
#     print (letter, " is sometimes a vowel."):
#
#     else:
#     print (letter, " is not a vowel!"

# %%
#char_in = input("Enter a character (be sure it is in quotes)")
#your code
'''char_in = input("Enter a letter:")
if char_in == 'a' or 'e' or 'i' or 'o' or 'u':
    print (char_in, " is a vowel.")
    
    #elif char_in == ('y')
    #print (char_in, " is sometimes a vowel."):
    
    else:
    print (char_in, " is not a vowel!"'''



'''char_in = input("Enter a letter:")
a = 10
e = 10
i = 10
o = 10
u = 10
y = 5
if char_in == 10
    print char_in " is a vowel."
elif char_in == 5
    print char_in " is sometimes a vowel."
else:
    print char_in " is not a vowel."'''

char_in = input("Enter a character in quotes:").lower()
if((char_in=="a")|(char_in=="e")|(char_in=="i")|(char_in=="o")|(char_in=="u")):
    print(char_in," is a vowel.")
else:
    print(char_in," is not a vowel")
# Out:
# Enter a character in quotes:'e'
# ('e', ' is a vowel.')

# %%
"d"
# Out:
# 'd'

# %% [markdown]
# Turn the following code into English

# %%
import random
#create a random assorment of numbers

a = random.choice(range(1,11))
# a = a random number between 1 and 11

b = 0
# be = 0

while (a != b):
#when a is not equal to b

    b = int(input("What? "))
#b = the input 

    if abs(a-b) > 4:
#if the absolute sum of a-b is > 4 print 'pfft'    
        print "Pfft"
    
    elif abs(a-b) > 2:
#if the absolute sum of a-b is > 2 print 'meh'
        print "Meh"
    
    elif abs(a-b)>0:
#if the absolute value of a-b is > 0 print 'hmmmm'
        print "Hmmmm"
    
    else:
        
        print "OK"
# Out:
# What? 99
# Pfft
# What? 1
# Hmmmm

# %% [markdown]
# Now modify it into readable code. Be sure to make variables for all the numbers

# %%
#No idea what his means
import random

a = random.choice(range(1,11))

b = 0

while (a != b):

    b = int(input("What? "))
    
    if abs(a-b) > 4:
    
        print "Pfft"
    
    elif abs(a-b) > 2:
    
        print "Meh"
    
    elif abs(a-b)>0:
    
        print "Hmmmm"
    
    else:
    
        print "OK"
# Out:
# What? 999
# Pfft
# What? 1
# Pfft
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-76ecdfa5aaf2> in <module>()
#       8 while (a != b):
#       9
# ---> 10     b = int(input("What? "))
#      11
#      12     if abs(a-b) > 4:
#
# /Users/EvanLSC/anaconda/lib/python2.7/site-packages/ipykernel/ipkernel.pyc in <lambda>(prompt)
#     139             self._sys_eval_input = builtin_mod.input
#     140             builtin_mod.raw_input = self.raw_input
# --> 141             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     142         self._save_getpass = getpass.getpass
#     143         getpass.getpass = self.getpass
#
# /Users/EvanLSC/anaconda/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     649             self._parent_ident,
#     650             self._parent_header,
# ...

# %% [markdown]
# Write an algorithm to print the lyrics to "99 Bottles of Beer on the Wall"
# 99 bottles of beer on the wall, 99 bottles of beer.
# Take one down, pass it around, 98 bottles of beer on the wall.
# 98 bottles of beer on the wall, 98 bottles of beer.
# Take one down, pass it around, 97 bottles of beer on the wall.
# ...
# no more bottles of beer on the wall.

# %%
for beers in xrange(99, 0, -1):
    if beers <= -1:
    elif:
        print 'No more bottles of beer on the wall'
        print beers, 'bottle%s of beer on the the wall.' % ('s', '')[beers == 1]
        print beers, 'bottle%s of beer.' % ('s', '')[beers == 1]
        print 'Take one down, pass it around.'
        print beers - 1, 'bottle%s of beer on the wall.\n' % ('s', '')[beers - 1 == 1]
# Out:
#   File "<ipython-input-49-f49084dbdc24>", line 3
#     elif:
#        ^
# IndentationError: expected an indented block

# %% [markdown]
# For the brave, implement your algorithm in Python

# %%
for beers in range(99, 0,-1):
    print beers, 'bottle%s of beer on the the wall.' % ('s', '')[beers == 1]
    print beers, 'bottle%s of beer.' % ('s', '')[beers == 1]
    print 'Take one down, pass it around.'
    print beers - 1, 'bottle%s of beer on the wall.\n' % ('s', '')[beers - 1 == 1]
# Out:
#  99 bottles of beer on the the wall.
# 99 bottles of beer.
# Take one down, pass it around.
# 98 bottles of beer on the wall.
#
# 98 bottles of beer on the the wall.
# 98 bottles of beer.
# Take one down, pass it around.
# 97 bottles of beer on the wall.
#
# 97 bottles of beer on the the wall.
# 97 bottles of beer.
# Take one down, pass it around.
# 96 bottles of beer on the wall.
#
# 96 bottles of beer on the the wall.
# 96 bottles of beer.
# Take one down, pass it around.
# 95 bottles of beer on the wall.
#
# 95 bottles of beer on the the wall.
# 95 bottles of beer.
# Take one down, pass it around.
# 94 bottles of beer on the wall.
#
# 94 bottles of beer on the the wall.
# 94 bottles of beer.
# Take one down, pass it around.
# 93 bottles of beer on the wall.
#
# 93 bottles of beer on the the wall.
# 93 bottles of beer.
# Take one down, pass it around.
# 92 bottles of beer on the wall.
#
# 92 bottles of beer on the the wall.
# 92 bottles of beer.
# Take one down, pass it around.
# ...

# %%
'''
song1 = "bottles of beer on the wall"
song2 = "bottles of beer"
chorus1 = "take one down pass it around"
chorus2 = "bottels of beer on the wall"
'''

# %%
#for loops the variable    in range defines the limits the sample the variable operates
for beers in range(99, 0, -1):
#if variable is > 1 print out the lyrics with the current value of the variable     
    if beers > 1:

        print beers, "bottles of beer on the wall."
        print beers, "bottles of beer."

        if beers > 2:

            suffix = str(beers - 1) + " bottles of beer on the wall."

        else:
            
            suffix = "1 bottle of beer on the wall."
    
    elif quant == 1:
        
        print "1 bottle of beer on the wall, 1 bottle of beer."
        
        suffix = "Time to buy more beer!"
    
    print "Take one down, pass it around,", suffix
    
    print ""
# Out:
# 99 bottles of beer on the wall,
# 99 bottles of beer.
# Take one down, pass it around, 98 bottles of beer on the wall.
#
# 98 bottles of beer on the wall,
# 98 bottles of beer.
# Take one down, pass it around, 97 bottles of beer on the wall.
#
# 97 bottles of beer on the wall,
# 97 bottles of beer.
# Take one down, pass it around, 96 bottles of beer on the wall.
#
# 96 bottles of beer on the wall,
# 96 bottles of beer.
# Take one down, pass it around, 95 bottles of beer on the wall.
#
# 95 bottles of beer on the wall,
# 95 bottles of beer.
# Take one down, pass it around, 94 bottles of beer on the wall.
#
# 94 bottles of beer on the wall,
# 94 bottles of beer.
# Take one down, pass it around, 93 bottles of beer on the wall.
#
# 93 bottles of beer on the wall,
# 93 bottles of beer.
# Take one down, pass it around, 92 bottles of beer on the wall.
#
# 92 bottles of beer on the wall,
# 92 bottles of beer.
# Take one down, pass it around, 91 bottles of beer on the wall.
#
# ...
